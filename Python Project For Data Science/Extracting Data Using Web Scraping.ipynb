# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/netflix_data_webpage.html'
html_data = requests.get(url)

# %%
html_data  = html_data.text

# %%
soup = BeautifulSoup(html_data, 'lxml')

# %%
netflix_data = pd.DataFrame(columns=["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume"])

for row in soup.find('tbody').find_all('tr'):
    data = row.find_all('td')
    date = data[0].text
    Open = data[1].text
    high = data[2].text
    low  = data[3].text
    close = data[4].text
    adj_close = data[5].text
    volume = data[6].text
    
    netflix_data = netflix_data.append({'Date' : date, 'Open':Open, 'High': high, 'Low': low, 'Close': close, "Adj Close":adj_close, 'Volume': volume}, ignore_index=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14272\2106953495.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   netflix_data = netflix_data.append({'Date' : date, 'Open':Open, 'High': high, 'Low': low, 'Close': close, "Adj Close":adj_close, 'Volume': volume}, ignore_index=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_14272\2106953495.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   netflix_data = netflix_data.append({'Date' : date, 'Open':Open, 'High': high, 'Low': low, 'Close': close, "Adj Close":adj_close, 'Volume': volume}, ignore_index=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_14272\2106953495.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
netflix_data
# Out:
#             Date      Open      High       Low     Close Adj Close  \
# 0   Jan 01, 2021  3,270.00  3,363.89  3,086.00  3,206.20  3,206.20
# 1   Dec 01, 2020  3,188.50  3,350.65  3,072.82  3,256.93  3,256.93
# 2   Nov 01, 2020  3,061.74  3,366.80  2,950.12  3,168.04  3,168.04
# 3   Oct 01, 2020  3,208.00  3,496.24  3,019.00  3,036.15  3,036.15
# 4   Sep 01, 2020  3,489.58  3,552.25  2,871.00  3,148.73  3,148.73
# ..           ...       ...       ...       ...       ...       ...
# 56  May 01, 2016    663.92    724.23    656.00    722.79    722.79
# 57  Apr 01, 2016    590.49    669.98    585.25    659.59    659.59
# 58  Mar 01, 2016    556.29    603.24    538.58    593.64    593.64
# 59  Feb 01, 2016    578.15    581.80    474.00    552.52    552.52
# 60  Jan 01, 2016    656.29    657.72    547.18    587.00    587.00
#
#          Volume
# 0    71,528,900
# 1    77,556,200
# 2    90,810,500
# 3   116,226,100
# 4   115,899,300
# ..          ...
# 56   90,614,500
# 57   78,464,200
# ...

# %%
netflix_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       61 non-null     object
#  1   Open       61 non-null     object
#  2   High       61 non-null     object
#  3   Low        61 non-null     object
#  4   Close      61 non-null     object
#  5   Adj Close  61 non-null     object
#  6   Volume     61 non-null     object
# dtypes: object(7)
# memory usage: 3.5+ KB

# %%
netflix_data.loc[len(netflix_data) -1, 'Open']
# Out:
# '656.29'

# %%
netflix_data.to_csv('netflix_data')

# %% [markdown]
# # Amazon Data

# %%
html_data = requests.get('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/amazon_data_webpage.html').text

# %%
soup = BeautifulSoup(html_data, 'lxml')

# %%
soup.title
# Out:
# <title>Amazon.com, Inc. (AMZN) Stock Historical Prices &amp; Data - Yahoo Finance</title>

# %%
amazon_data = pd.DataFrame(columns=["Date", "Open", "High", "Low", "Close", "Volume"])

for row in soup.find("tbody").find_all("tr"):
    col = row.find_all("td")
    date = col[0].text
    Open = col[1].text
    high = col[2].text
    low = col[3].text
    close = col[4].text
    adj_close = col[5].text
    volume = col[6].text
    
    amazon_data = amazon_data.append({"Date":date, "Open":Open, "High":high, "Low":low, "Close":close, "Adj Close":adj_close, "Volume":volume}, ignore_index=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14272\601426831.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   amazon_data = amazon_data.append({"Date":date, "Open":Open, "High":high, "Low":low, "Close":close, "Adj Close":adj_close, "Volume":volume}, ignore_index=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_14272\601426831.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   amazon_data = amazon_data.append({"Date":date, "Open":Open, "High":high, "Low":low, "Close":close, "Adj Close":adj_close, "Volume":volume}, ignore_index=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_14272\601426831.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
amazon_data.head()
# Out:
#            Date      Open      High       Low     Close       Volume Adj Close
# 0  Jan 01, 2021  3,270.00  3,363.89  3,086.00  3,206.20   71,528,900  3,206.20
# 1  Dec 01, 2020  3,188.50  3,350.65  3,072.82  3,256.93   77,556,200  3,256.93
# 2  Nov 01, 2020  3,061.74  3,366.80  2,950.12  3,168.04   90,810,500  3,168.04
# 3  Oct 01, 2020  3,208.00  3,496.24  3,019.00  3,036.15  116,226,100  3,036.15
# 4  Sep 01, 2020  3,489.58  3,552.25  2,871.00  3,148.73  115,899,300  3,148.73

# %%
amazon_data.to_csv('amazon_data')
